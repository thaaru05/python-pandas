# %%
import pandas as pd

# Provide the correct path to your CSV file
file_path = r'C:\Users\ADMIN\Desktop\PROJECT\home-credit-credit-risk-model-stability\csv_files\test\test_applprev_1_0.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# %%
# Display the DataFrame
print(df)
# Out:
#    case_id  actualdpd_943P  annuity_853A  approvaldate_319D  \
# 0    57543             0.0     1519.8000                NaN
# 1    57549             0.0     2048.8000                NaN
# 2    57551             0.0     1871.8000                NaN
# 3    57551             0.0     5401.0000                NaN
# 4    57552             0.0     4834.2000                NaN
# 5    57632             0.0     6390.2000                NaN
# 6    57633             0.0        0.0000                NaN
# 7    57633             0.0     6336.8003                NaN
# 8    57633             0.0     3290.8000                NaN
# 9    57633             0.0     7524.2000                NaN
#
#    byoccupationinc_3656910L cancelreason_3545846M  childnum_21L  \
# 0                       NaN           P94_109_143           NaN
# 1                       NaN           P94_109_143           NaN
# 2                       NaN           P94_109_143           NaN
# ...

# %%
#shape of the DataFrame 
df.shape
# Out:
# (10, 41)

# %%
df.info()
#info of the DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 41 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   case_id                      10 non-null     int64
#  1   actualdpd_943P               10 non-null     float64
#  2   annuity_853A                 10 non-null     float64
#  3   approvaldate_319D            0 non-null      float64
#  4   byoccupationinc_3656910L     0 non-null      float64
#  5   cancelreason_3545846M        10 non-null     object
#  6   childnum_21L                 1 non-null      float64
#  7   creationdate_885D            10 non-null     object
#  8   credacc_actualbalance_314A   0 non-null      float64
#  9   credacc_credlmt_575A         10 non-null     float64
#  10  credacc_maxhisbal_375A       0 non-null      float64
#  11  credacc_minhisbal_90A        0 non-null      float64
#  12  credacc_status_367L          0 non-null      float64
# ...

# %%
#to set various options to customize the behavior and display of pandas objects
#pd.set_option(option, value)
# Set the maximum number of rows and columns to be displayed
pd.set_option('display.max_rows', 1)
pd.set_option('display.max_columns', 2)

# Set the precision for floating-point numbers
pd.set_option('display.precision', 2)

df
# Out:
#     case_id  ...  tenor_203L
# 0     57543  ...        31.0
# ..      ...  ...         ...
#
# [10 rows x 41 columns]

# %%
#this code imports the pandas library, defines the file path to a CSV file, and reads that CSV file into a pandas DataFrame named schema_df
file_path = r'C:\Users\ADMIN\Desktop\PROJECT\home-credit-credit-risk-model-stability\csv_files\test\test_applprev_1_0.csv'
schema_df = pd.read_csv(file_path)
pd.set_option('display.max_rows', 5)
pd.set_option('display.max_columns', 6)
print(schema_df)
# Out:
#     case_id  actualdpd_943P  annuity_853A  ...  revolvingaccount_394A  \
# 0     57543             0.0        1519.8  ...                    NaN
# 1     57549             0.0        2048.8  ...                    NaN
# ..      ...             ...           ...  ...                    ...
# 8     57633             0.0        3290.8  ...                    NaN
# 9     57633             0.0        7524.2  ...                    NaN
#
#     status_219L tenor_203L
# 0             D       31.0
# 1             D       12.0
# ..          ...        ...
# 8             D       18.0
# 9             D        3.0
#
# [10 rows x 41 columns]

# %%
df.head()
#viewing certain number of records from top
#only five records displayed because we have set the options for max rows = 5
# Out:
#    case_id  actualdpd_943P  annuity_853A  ...  revolvingaccount_394A  \
# 0    57543             0.0        1519.8  ...                    NaN
# 1    57549             0.0        2048.8  ...                    NaN
# 2    57551             0.0        1871.8  ...                    NaN
# 3    57551             0.0        5401.0  ...                    NaN
# 4    57552             0.0        4834.2  ...                    NaN
#
#    status_219L tenor_203L
# 0            D       31.0
# 1            D       12.0
# 2            D       12.0
# 3            D       18.0
# 4            D       18.0
#
# [5 rows x 41 columns]

# %%
df.tail()
#viewing certain number of records from bottom
# Out:
#    case_id  actualdpd_943P  annuity_853A  ...  revolvingaccount_394A  \
# 5    57632             0.0        6390.2  ...                    NaN
# 6    57633             0.0           0.0  ...                    NaN
# 7    57633             0.0        6336.8  ...                    NaN
# 8    57633             0.0        3290.8  ...                    NaN
# 9    57633             0.0        7524.2  ...                    NaN
#
#    status_219L tenor_203L
# 5            T       24.0
# 6            D        NaN
# 7            T       36.0
# 8            D       18.0
# 9            D        3.0
#
# [5 rows x 41 columns]
